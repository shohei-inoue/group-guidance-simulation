# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import patches
import math

# %%
plt.style.use('seaborn-whitegrid')

# %%
SAVE_DIRECTORY = 'csv/'

# %%
red_df_list = []

# %%
red_num = int(input('Please enter the number of red. : '))

# %%
# RedのCSVファイルを読み込み
for i in range(red_num):
    df = pd.read_csv(SAVE_DIRECTORY + 'red' + str(i + 1) + '.csv')
    red_df_list.append(df)

# %%
marker_df = pd.read_csv(SAVE_DIRECTORY + "marker.csv")

# %%
marker_df_list = []

# %%
obstacle_num = int(input('Please enter the number of obstacle.'))

# %%
# マップ(全体)のCSVファイルの読み込み
obstacle_df_list = []
for i in range(obstacle_num):
  df = pd.read_csv(SAVE_DIRECTORY + 'obstacle' + str(i + 1) + '.csv')
  obstacle_df_list.append(df)

# %%
x_list = []
y_list = []
for i in range(red_num):
  x_list.append(red_df_list[i]['x'])
  y_list.append(red_df_list[i]['y'])

# %%
# ランダムウォークのみの出力
x = x_list[2]
y = y_list[2]
plt.plot(x, y, '-or', linewidth=0.5)
plt.show()

# %%
# マーカーを加えた出力
x = x_list[0]
y = y_list[0]
plt.plot(x, y, '-or', linewidth=0.5)
plt.plot(marker_df['x'], marker_df['y'], 'sb')
plt.show()

# %%
# 障害物を加えた出力
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(1, 1, 1, aspect="equal")
x = x_list[0]
y = y_list[0]
plt.plot(x, y, '-or', linewidth=0.5)
plt.plot(marker_df['x'], marker_df['y'], 'sb')
obstacle = patches.Rectangle(
    xy = (obstacle_df_list[1].iloc[0, 1], obstacle_df_list[1].iloc[0, 2]),
    width = obstacle_df_list[1].iloc[0, 5],
    height = obstacle_df_list[1].iloc[0, 4],
    angle = 0,
    facecolor = "b",
    edgecolor = "c",
    linewidth = 3,
    fill = True,
)
ax.add_patch(obstacle)
obstacle = patches.Rectangle(
    xy = (obstacle_df_list[2].iloc[0, 1], obstacle_df_list[2].iloc[0, 2]),
    width = obstacle_df_list[2].iloc[0, 5],
    height = obstacle_df_list[2].iloc[0, 4],
    angle = 0,
    facecolor = "b",
    edgecolor = "c",
    linewidth = 3,
    fill = True,
)
ax.add_patch(obstacle)
obstacle = patches.Rectangle(
    xy = (obstacle_df_list[0].iloc[0, 1], obstacle_df_list[0].iloc[0, 2]),
    width = obstacle_df_list[0].iloc[0, 5],
    height = obstacle_df_list[0].iloc[0, 4],
    angle = 0,
    facecolor = "b",
    edgecolor = "c",
    linewidth = 3,
    fill = True,
)
ax.add_patch(obstacle)
obstacle = patches.Rectangle(
    xy = (obstacle_df_list[3].iloc[0, 1], obstacle_df_list[3].iloc[0, 2]),
    width = obstacle_df_list[3].iloc[0, 5],
    height = obstacle_df_list[3].iloc[0, 4],
    angle = 0,
    facecolor = "b",
    edgecolor = "c",
    linewidth = 3,
    fill = True,
)
ax.add_patch(obstacle)
obstacle = patches.Rectangle(
    xy = (obstacle_df_list[4].iloc[0, 1], obstacle_df_list[4].iloc[0, 2]),
    width = obstacle_df_list[4].iloc[0, 5],
    height = obstacle_df_list[4].iloc[0, 4],
    angle = 0,
    facecolor = "b",
    edgecolor = "c",
    linewidth = 3,
    fill = True,
)
ax.add_patch(obstacle)
obstacle = patches.Rectangle(
    xy = (obstacle_df_list[5].iloc[0, 1], obstacle_df_list[5].iloc[0, 2]),
    width = obstacle_df_list[5].iloc[0, 5],
    height = obstacle_df_list[5].iloc[0, 4],
    angle = 0,
    facecolor = "b",
    edgecolor = "c",
    linewidth = 3,
    fill = True,
)
ax.add_patch(obstacle)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/bh/rzy3f__j115804r6w338qgrr0000gn/T/ipykernel_34285/1377777169.py in <module>
#      62 ax.add_patch(obstacle)
#      63 obstacle = patches.Rectangle(
# ---> 64     xy = (obstacle_df_list[5].iloc[0, 1], obstacle_df_list[5].iloc[0, 2]),
#      65     width = obstacle_df_list[5].iloc[0, 5],
#      66     height = obstacle_df_list[5].iloc[0, 4],
#
# IndexError: list index out of range

# %%
# Red複数台での出力
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(1, 1, 1, aspect="equal")

for i in range(red_num):
    plt.plot(x_list[i], y_list[i], '-o', linewidth=0.5)
plt.plot(marker_df['x'], marker_df['y'], 'sb')

obstacle1 = patches.Rectangle(
    xy = (obstacle_df_list[1].iloc[0, 1], obstacle_df_list[1].iloc[0, 2]),
    width = obstacle_df_list[1].iloc[0, 5],
    height = obstacle_df_list[1].iloc[0, 4],
    angle = 0,
    facecolor = "b",
    edgecolor = "c",
    linewidth = 3,
    fill = True,
)
ax.add_patch(obstacle1)
obstacle2 = patches.Rectangle(
    xy = (obstacle_df_list[2].iloc[0, 1], obstacle_df_list[2].iloc[0, 2]),
    width = obstacle_df_list[2].iloc[0, 5],
    height = obstacle_df_list[2].iloc[0, 4],
    angle = 0,
    facecolor = "b",
    edgecolor = "c",
    linewidth = 3,
    fill = True,
)
ax.add_patch(obstacle2)
obstacle3 = patches.Rectangle(
    xy = (obstacle_df_list[0].iloc[0, 1], obstacle_df_list[0].iloc[0, 2]),
    width = obstacle_df_list[0].iloc[0, 5],
    height = obstacle_df_list[0].iloc[0, 4],
    angle = 0,
    facecolor = "b",
    edgecolor = "c",
    linewidth = 3,
    fill = True,
)
ax.add_patch(obstacle3)
obstacle4 = patches.Rectangle(
    xy = (obstacle_df_list[3].iloc[0, 1], obstacle_df_list[3].iloc[0, 2]),
    width = obstacle_df_list[3].iloc[0, 5],
    height = obstacle_df_list[3].iloc[0, 4],
    angle = 0,
    facecolor = "b",
    edgecolor = "c",
    linewidth = 3,
    fill = True,
)
ax.add_patch(obstacle4)
obstacle5 = patches.Rectangle(
    xy = (obstacle_df_list[4].iloc[0, 1], obstacle_df_list[4].iloc[0, 2]),
    width = obstacle_df_list[4].iloc[0, 5],
    height = obstacle_df_list[4].iloc[0, 4],
    angle = 0,
    facecolor = "b",
    edgecolor = "c",
    linewidth = 3,
    fill = True,
)
ax.add_patch(obstacle5)
plt.show()

# %%
# 動画の作成
# %matplotlib nbagg
import itertools
import math
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import patches
from matplotlib import animation

def _update(frame, x, y):
    plt.cla()
    for i in range(red_num):
        x[i].append(x_list[i][frame])
        y[i].append(y_list[i][frame])
    
    plt.plot(marker_df['x'], marker_df['y'], 'sr', label="marker")
    
    for i in range(red_num):
        plt.plot(x[i], y[i], '-o', linewidth=0.5, label="red" + str(i+1))
    
    obstacle1 = patches.Rectangle(
        xy = (obstacle_df_list[0].iloc[0, 1], obstacle_df_list[0].iloc[0, 2]),
        width = obstacle_df_list[0].iloc[0, 5],
        height = obstacle_df_list[0].iloc[0, 4],
        angle = 0,
        facecolor = "b",
        edgecolor = "c",
        linewidth = 3,
        fill = True,
    )
    ax.add_patch(obstacle1)
    obstacle2 = patches.Rectangle(
        xy = (obstacle_df_list[1].iloc[0, 1], obstacle_df_list[1].iloc[0, 2]),
        width = obstacle_df_list[1].iloc[0, 5],
        height = obstacle_df_list[1].iloc[0, 4],
        angle = 0,
        facecolor = "b",
        edgecolor = "c",
        linewidth = 3,
        fill = True,
    )
    ax.add_patch(obstacle2)
    obstacle3 = patches.Rectangle(
        xy = (obstacle_df_list[2].iloc[0, 1], obstacle_df_list[2].iloc[0, 2]),
        width = obstacle_df_list[2].iloc[0, 5],
        height = obstacle_df_list[2].iloc[0, 4],
        angle = 0,
        facecolor = "b",
        edgecolor = "c",
        linewidth = 3,
        fill = True,
    )
    ax.add_patch(obstacle3)
    obstacle4 = patches.Rectangle(
        xy = (obstacle_df_list[3].iloc[0, 1], obstacle_df_list[3].iloc[0, 2]),
        width = obstacle_df_list[3].iloc[0, 5],
        height = obstacle_df_list[3].iloc[0, 4],
        angle = 0,
        facecolor = "b",
        edgecolor = "c",
        linewidth = 3,
        fill = True,
    )
    ax.add_patch(obstacle4)
    obstacle5 = patches.Rectangle(
        xy = (obstacle_df_list[4].iloc[0, 1], obstacle_df_list[4].iloc[0, 2]),
        width = obstacle_df_list[4].iloc[0, 5],
        height = obstacle_df_list[4].iloc[0, 4],
        angle = 0,
        facecolor = "b",
        edgecolor = "c",
        linewidth = 3,
        fill = True,
    )
    ax.add_patch(obstacle5)
    #obstacle6 = patches.Rectangle(
    #    xy = (obstacle_df_list[5].iloc[0, 1], obstacle_df_list[5].iloc[0, 2]),
    #    width = obstacle_df_list[5].iloc[0, 5],
    #    height = obstacle_df_list[5].iloc[0, 4],
    #    angle = 0,
    #    facecolor = "b",
    #    edgecolor = "c",
    #    linewidth = 3,
    #    fill = True,
    #)
    #ax.add_patch(obstacle6)
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0, fontsize=18)
    plt.show()

fig = plt.figure(figsize=(16, 9))
ax = fig.add_subplot(1, 1, 1, aspect="equal")

x = []
y = []
for i in range(red_num):
    x.append([])
    y.append([])

params = {
    'fig': fig,
    'func': _update,
    'fargs': (x, y),
    'interval': 10,
    'frames': np.arange(0, len(red_df_list[0]['step']), 1),
    'repeat': False,
}

anime = animation.FuncAnimation(**params)
anime.save('video/sim_video.gif', writer='pillow')

# %%
# 障害物がない場合の動画の作成
# %matplotlib nbagg
import itertools
import math
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import patches
from matplotlib import animation


def _update(frame, x, y):
    plt.cla()
    for i in range(red_num):
        x[i].append(x_list[i][frame])
        y[i].append(y_list[i][frame])
    
    plt.plot(marker1_df['x'], marker1_df['y'], 'sb', label="real_marker1")
    plt.plot(marker2_df['x'], marker2_df['y'], 'sr', label="real_marker2")
    plt.plot(vmarker_df['x'], vmarker_df['y'], 'sg', label="virtual_marker")
    
    for i in range(red_num):
        plt.plot(x[i], y[i], '-o', linewidth=0.5, label="red" + str(i+1))
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0, fontsize=18)
    plt.show()


fig = plt.figure(figsize=(16, 9))
x = []
y = []
for i in range(red_num):
    x.append([])
    y.append([])

params = {
    'fig': fig,
    'func': _update,
    'fargs': (x, y),
    'interval': 10,
    'frames': np.arange(0, len(red_df_list[0]['step']), 1),
    'repeat': False,
}

anime = animation.FuncAnimation(**params)
anime.save('video/sim_video_no_obstacle.gif', writer='pillow')

# %%
# Red複数台での出力
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(1, 1, 1, aspect="equal")

for i in range(red_num):
    plt.plot(x_list[i], y_list[i], '-o', linewidth=0.5)
plt.plot(marker1_df['x'], marker1_df['y'], 'sb')
plt.plot(marker2_df['x'], marker2_df['y'], 'sb')
plt.plot(vmarker_df['x'], vmarker_df['y'], 'sb')
for i in range(red_num):
        plt.plot(collision_list[i]['x'], collision_list[i]['y'], 'Xk')

plt.show()

# %%
fig = plt.figure(figsize=(9, 9))
for i in range(red_num):
        plt.plot(collision_list[i]['x'], collision_list[i]['y'], 'X')

plt.savefig("obstacle.png")

# %%
collision_list = []

# %%
for i in range(red_num):
  collision = red_df_list[i][red_df_list[i]['collision_flag'] == 1]
  collision_list.append(collision)

# %%
fig = plt.figure(figsize=(16, 9))
ax = fig.add_subplot(1, 1, 1, aspect="equal")


for i in range(red_num):
    plt.plot(collision_list[i]['x'], collision_list[i]['y'], 'X')
# 長方形
obstacle = patches.Rectangle(
    xy = (obstacle_df_list[1].iloc[0, 1], obstacle_df_list[1].iloc[0, 2]),
    width = obstacle_df_list[1].iloc[0, 5],
    height = obstacle_df_list[1].iloc[0, 4],
    angle = 0,
    facecolor = "b",
    edgecolor = "c",
    linewidth = 3,
    fill = True,
)
ax.add_patch(obstacle)
obstacle = patches.Rectangle(
    xy = (obstacle_df_list[2].iloc[0, 1], obstacle_df_list[2].iloc[0, 2]),
    width = obstacle_df_list[2].iloc[0, 5],
    height = obstacle_df_list[2].iloc[0, 4],
    angle = 0,
    facecolor = "b",
    edgecolor = "c",
    linewidth = 3,
    fill = True,
)
ax.add_patch(obstacle)
obstacle = patches.Rectangle(
    xy = (obstacle_df_list[0].iloc[0, 1], obstacle_df_list[0].iloc[0, 2]),
    width = obstacle_df_list[0].iloc[0, 5],
    height = obstacle_df_list[0].iloc[0, 4],
    angle = 0,
    facecolor = "b",
    edgecolor = "c",
    linewidth = 3,
    fill = True,
)
ax.add_patch(obstacle)
plt.show()

# %%
red_df_list[0]

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(1, 1, 1, aspect="equal")

for i in range(red_num):
        plt.plot(collision_list[i]['x'], collision_list[i]['y'], 'X')

obstacle = patches.Rectangle(
    xy = (obstacle_df_list[1].iloc[0, 1], obstacle_df_list[1].iloc[0, 2]),
    width = obstacle_df_list[1].iloc[0, 5],
    height = obstacle_df_list[1].iloc[0, 4],
    angle = 0,
    facecolor = "b",
    edgecolor = "c",
    linewidth = 3,
    fill = True,
)
ax.add_patch(obstacle)
obstacle = patches.Rectangle(
    xy = (obstacle_df_list[2].iloc[0, 1], obstacle_df_list[2].iloc[0, 2]),
    width = obstacle_df_list[2].iloc[0, 5],
    height = obstacle_df_list[2].iloc[0, 4],
    angle = 0,
    facecolor = "b",
    edgecolor = "c",
    linewidth = 3,
    fill = True,
)
ax.add_patch(obstacle)
obstacle = patches.Rectangle(
    xy = (obstacle_df_list[0].iloc[0, 1], obstacle_df_list[0].iloc[0, 2]),
    width = obstacle_df_list[0].iloc[0, 5],
    height = obstacle_df_list[0].iloc[0, 4],
    angle = 0,
    facecolor = "b",
    edgecolor = "c",
    linewidth = 3,
    fill = True,
)
ax.add_patch(obstacle)
plt.show()

# %%
pseudo_obstacle_df = pd.read_csv(SAVE_DIRECTORY + 'pseudo_obstacle.csv')

# %%
pseudo_obstacle_df
# Out:
#      Unnamed: 0   center_x   center_y                 center_point  height  \
# 0             0   0.098489 -32.768476  [-45.           9.29811557]     1.0
# 1             0  -0.091192 -32.118807  [-45.           8.72756006]     1.0
# 2             0  -0.006517 -31.486149  [-45.           0.91611613]     1.0
# 3             0 -45.000000   8.727560  [-45.           8.72756006]     1.0
# 4             0 -45.000000  10.263994  [-45.          10.26399389]     1.0
# ..          ...        ...        ...                          ...     ...
# 912           0  45.000000  19.851966      [45.        19.8519659]     1.0
# 913           0  45.000000  22.080194    [45.         22.08019372]     1.0
# 914           0  45.000000  31.222551    [45.         31.22255057]     1.0
# 915           0  45.000000  22.849740      [45.        22.8497396]     1.0
# 916           0  45.000000  25.401999    [45.         25.40199922]     1.0
#
#          width
# 0    32.311560
# 1    32.612821
# 2    32.156531
# ...

# %%
pseudo_obstacle_df['center_x'][0]

# %%
#input
import matplotlib.pyplot as plt
import matplotlib.patches as pat

fig = plt.figure(figsize=(12, 12))

ax = fig.add_subplot(111)
ax.set_xlim(-50, 50)
ax.set_ylim(-50, 50)

for i in range(len(pseudo_obstacle_df)):
    E = pat.Ellipse(
        xy=(pseudo_obstacle_df['center_x'][i], pseudo_obstacle_df['center_y'][i]), 
        width=pseudo_obstacle_df['width'][i], 
        height=pseudo_obstacle_df['height'][i]
        )
    ax.add_patch(E)

plt.show()
